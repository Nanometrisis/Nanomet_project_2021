# %% [markdown]
# ## Description

# %% [markdown]
# In this notebook we show information regarding the nanomet dataset and create a model that predicts the reflectivity value of a determined nanostructured surface.
#
# Specifically, we train Neural networks with the Keras library

# %% [markdown]
# ### 1) Import libraries

# %%
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std
import random

import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
import pickle
import glob

from sklearn.model_selection import train_test_split

from sklearn.datasets import make_regression
from sklearn.model_selection import RepeatedKFold
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense

import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)

from sklearn import metrics
from sklearn.model_selection import KFold


# define a quick function for mean relative absolute error
def mean_relative_absolute_error(y_true, y_pred):
    x=sum(np.abs((y_true - y_pred)) / y_true ) /len(y_true)
    return x

# %%
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import RepeatedKFold

from tensorflow import keras
from tensorflow.keras.layers import *


from tensorflow.keras.models import Sequential

# %%
#import tensorflow as tf

#import autokeras as ak

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### 2) Data exploration and analysis

# %%
#read the data with pandas and convert to a dataframe
df2 = pd.read_csv("../data/grating_nanomet_v1.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

# %%
#Add index simulation based on unique input values
df_col = df2.groupby(['h','top','base']).size().reset_index().rename(columns={0:'count'})
df3 = df2.reset_index().rename(columns = {'index': 'Simulation index'}, inplace = False)

i=1
for index, row in df_col.iterrows():
    df3.loc[(df3['h'] == row['h']) & (df3['top'] == row['top']) & (df3['base'] == row['base']),'Simulation index'] = i
    i+=1

# %%
df3.value_counts()
# Out:
# Simulation index  h    top  base   wavelength  Reflectance
# 1                 80   10   10.0   400.000000  0.044171       1
# 67                160  40   52.5   612.121212  0.020993       1
#                                    590.909091  0.019761       1
#                                    593.939394  0.020019       1
#                                    596.969697  0.020229       1
#                                                              ..
# 34                120  20   57.5   500.000000  0.017134       1
#                                    503.030303  0.016927       1
#                                    506.060606  0.016725       1
#                                    509.090909  0.016535       1
# 100               200  50   100.0  700.000000  0.012974       1
# Length: 10000, dtype: int64

# %%
df3.describe()
# Out:
#        Simulation index             h           top          base  \
# count      10000.000000  10000.000000  10000.000000  10000.000000
# mean          50.500000    140.000000     30.000000     55.000000
# std           28.867513     44.723596     14.142843     22.639595
# min            1.000000     80.000000     10.000000     10.000000
# 25%           25.750000    110.000000     20.000000     40.000000
# 50%           50.500000    140.000000     30.000000     55.000000
# 75%           75.250000    170.000000     40.000000     70.000000
# max          100.000000    200.000000     50.000000    100.000000
#
#          wavelength   Reflectance
# count  10000.000000  10000.000000
# mean     550.000000      0.025581
# std       87.477314      0.011547
# min      400.000000      0.000936
# 25%      475.000000      0.017444
# 50%      550.000000      0.025111
# 75%      625.000000      0.032912
# max      700.000000      0.055296

# %%
len(df3['base'].unique())
# Out:
# 25

# %%
df3[3900:4000]
# Out:
#       Simulation index    h  top  base  wavelength  Reflectance
# 3900                40  120   30  80.0  400.000000     0.013633
# 3901                40  120   30  80.0  403.030303     0.015904
# 3902                40  120   30  80.0  406.060606     0.016310
# 3903                40  120   30  80.0  409.090909     0.016411
# 3904                40  120   30  80.0  412.121212     0.016381
# ...                ...  ...  ...   ...         ...          ...
# 3995                40  120   30  80.0  687.878788     0.013889
# 3996                40  120   30  80.0  690.909091     0.014151
# 3997                40  120   30  80.0  693.939394     0.014414
# 3998                40  120   30  80.0  696.969697     0.014680
# 3999                40  120   30  80.0  700.000000     0.014947
#
# [100 rows x 6 columns]

# %%
a4_dims = (8, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.lineplot(ax=ax,data=df3[3900:4000], x="wavelength", y='Reflectance')
plt.ylabel('Reflectivity',fontsize=12)
plt.xlabel('Wavelength (nm)',fontsize=12)
# Out:
# Text(0.5, 0, 'Wavelength (nm)')

# %% [markdown]
# ##### Ploting some of the spectrums

# %%
a4_dims = (8, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.lineplot(ax=ax,data=df3[1:4000], x="wavelength", y='Reflectance',hue = "Simulation index")
plt.ylabel('Reflectivity',fontsize=12)
plt.xlabel('Wavelength (nm)',fontsize=12)
# Out:
# Text(0.5, 0, 'Wavelength (nm)')

# %%
a4_dims = (8, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.lineplot(ax=ax,data=df3[4000:7000], x="wavelength", y='Reflectance',hue = "Simulation index")
plt.ylabel('Reflectivity',fontsize=12)
plt.xlabel('Wavelength (nm)',fontsize=12)
# Out:
# Text(0.5, 0, 'Wavelength (nm)')

# %%
a4_dims = (8, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.lineplot(ax=ax,data=df3[7000:10000], x="wavelength", y='Reflectance',hue = "Simulation index")
plt.ylabel('Reflectivity',fontsize=12)
plt.xlabel('Wavelength (nm)',fontsize=12)
# Out:
# Text(0.5, 0, 'Wavelength (nm)')

# %%
sns.pairplot(df3[['h','top','base','wavelength','Reflectance']])

# %% [markdown]
# ### 3) Feature Engineering

# %% [raw]
# #Separating the data into train and test involves randomness, therefore, we need to set the seed.
#
# # Let's separate into train and test set
# # Remember to set the seed (random_state for this sklearn function)
#
# X_train, X_test, y_train, y_test = train_test_split(
#     df3.drop(['Simulation index', 'Reflectance'], axis=1), # predictive variables
#     df3['Reflectance'], # target
#     test_size=0.2, # portion of dataset to allocate to test set
#     random_state=0, # we are setting the seed here
# )
#
# X_train.shape, X_test.shape

# %% [markdown]
# In the following cells, we will engineer the variables of our Dataset so that we tackle:
#
#
# * Put the variables in a similar scale
#
#
# Small note that for the Random forest model this is not required

# %% [markdown]
# ### 3) Feature Selection

# %% [markdown]
# Due to the low number of features, we are not going to add more.
#
# However, if we see that our models are not perfoming well we can combine some features to help the trainning! (Source: https://pubmed.ncbi.nlm.nih.gov/31684518/)

# %% [markdown]
# ### 5) Model Training

# %%
# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
#getting our features
features = df3.drop(['Simulation index', 'Reflectance'],axis= 1).columns.tolist()

# %% [markdown]
# #### 5.1) Neural Networks (Forward problem)

# %%
scaler_1 = MinMaxScaler()

df3[['h','top','base','wavelength']] = scaler_1.fit_transform(df3[['h','top','base','wavelength']])

# %%
#save min max scaler
import joblib
scaler_filename = "../minmaxscalers/forward_scaler.save"
joblib.dump(scaler_1, scaler_filename) 
scaler_1 = joblib.load(scaler_filename)

# %%
df4 = df3[(df3['Simulation index'] != 13) & (df3['Simulation index'] != 14) & (df3['Simulation index'] != 15) & (df3['Simulation index'] != 70) & (df3['Simulation index'] != 71)]

# %%
df5 = df3[(df3['Simulation index'] == 13) | (df3['Simulation index'] == 14) | (df3['Simulation index'] == 15) | (df3['Simulation index'] == 70) | (df3['Simulation index'] == 71)]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df4.drop(['Simulation index', 'Reflectance'], axis=1), # predictive variables
    df4['Reflectance'], # target
    test_size=0.2, # portion of dataset to allocate to test set
    random_state=8790, # we are setting the seed here
)

X_train.shape, X_test.shape
# Out:
# ((7600, 4), (1900, 4))

# %%
len(X_train)
# Out:
# 7600

# %%
# get the model
from keras.layers import LeakyReLU
def get_model(n_inputs, n_outputs):

	net1Model=keras.models.Sequential()
	net1Model.add(Dense(n_inputs,input_shape=(4,)))
	#net1Model.add(Activation('relu'))
	net1Model.add(Dense(240))
	net1Model.add(Activation('relu'))
	#net1Model.add(Dropout(0.5))
	net1Model.add(Dense(30))
	net1Model.add(Activation('relu'))
	#net1Model.add(Dropout(0.4))
#	net1Model.add(Dense(400))
#	net1Model.add(Dropout(0.6))
#	net1Model.add(Dense(400))
	#net1Model.add(Dropout(0.2))
	net1Model.add(Dense(1024))
    #net1Model.add(GaussianNoise(1.0))
	net1Model.add(Dense(n_outputs))
	net1Model.compile(optimizer='Adam',loss='mse')
    #net1Model.fit(X1, y1,epochs=1000,verbose=0)
	#model.compile(loss='mae', optimizer='adam')
    
	return net1Model

# %%
# get the model (new model)

# get the model
from keras.layers import LeakyReLU
def get_model(n_inputs, n_outputs):
    
	net1Model=keras.models.Sequential()
	net1Model.add(Dense(n_inputs,input_shape=(4,)))
	#net1Model.add(Activation('relu'))
	net1Model.add(Dense(240))
	net1Model.add(LeakyReLU(alpha=0.05))
	#net1Model.add(Dropout(0.5))
	net1Model.add(Dense(30))
	net1Model.add(LeakyReLU(alpha=0.05))
	#net1Model.add(Dropout(0.4))
#	net1Model.add(Dense(400))
#	net1Model.add(Dropout(0.6))
#	net1Model.add(Dense(400))
	#net1Model.add(Dropout(0.2))
	net1Model.add(Dense(1024))
    #net1Model.add(GaussianNoise(1.0))
	net1Model.add(Dense(n_outputs))
	net1Model.compile(optimizer='Adam',loss='mse')
    #net1Model.fit(X1, y1,epochs=1000,verbose=0)
	#model.compile(loss='mae', optimizer='adam')
    
	return net1Model

# %% [markdown]
# Here we train the model and show the error of the actual test values compared to the predicted ones from the random heldout test dataset
#
# If you want to see the training progress put verbose = 1

# %%
n_inputs, n_outputs = X_train.shape[1],1
model_forward = get_model(n_inputs, n_outputs)

# fit model
model_forward.fit(X_train, y_train, verbose=0, epochs=900)

# evaluate model on test set
#mae = model.evaluate(X_train, y_train, verbose=0)
mae = model_forward.evaluate(X_test, y_test, verbose=1)    
pred= model_forward.predict(X_test)

plt.figure(figsize=(9,7))
plt.scatter(pred,y_test,alpha=0.6,s=3)
plt.plot([0, 0.07],[0, 0.07],'r',alpha=0.8)
plt.ylabel('True Reflectivity',fontsize=15)
plt.xlabel('Predicted Reflectivity ',fontsize=15)
plt.title('Deep Neural Network (Train size= 80 spectra)',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([-0.01, 0.08])
plt.ylim([-0.01,  0.08])
plt.show()
# Out:
# ...
# 60/60 [==============================] - 0s 989us/step

# %%
#DELETE THIS LATER
#pre_heldout= model_forward.predict(df_test_out.drop(['Reflectance'], axis=1))
#np.sqrt(sklearn.metrics.mean_squared_error(df_test_out['Reflectance'], pre_heldout))/mean(extra_df['Reflectance'])
#DELETE THIS LATER

# %%
import sklearn
pred,y_test
sklearn.metrics.mean_absolute_error(y_test, pred)
# Out:
# 0.0001912275512576422

# %%
#save model to tf and tf lite form
import tensorflow as tf
from tensorflow import keras
model_forward.save('../models/model_forward_v5900')
#import keras tf model
model_path = '../models/model_forward_v5900'
model = tf.keras.models.load_model(model_path)

#convert
converter = tf.lite.TFLiteConverter.from_keras_model(model)

#Implement optimization strategy for smaller model sizes
#converter.optimizations = [tf.lite.Optimize.DEFAULT] #Uses default optimization strategy to reduce the model size
tflite_model = converter.convert()
open('../models/model_forward_v5900.tflite', "wb").write(tflite_model)
# Out:
# 163484

# %% [markdown]
# #### Test the data on heldout and train spectra

# %%
df_helout = df3[df3['Simulation index'] == 12]
pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
df_helout = df3[df3['Simulation index'] == 13]
pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
df_helout = df3[df3['Simulation index'] == 14]
pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
df_helout = df3[df3['Simulation index'] == 15]

pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately

plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 

plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
df_helout = df3[df3['Simulation index'] == 70]
pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
df_helout = df3[df3['Simulation index'] == 71]
pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
df_helout = df3[df3['Simulation index'] == 61]
pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
df_helout = df3[df3['Simulation index'] == 62]
pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
#What is the time for running modeling?

# %% [markdown]
# #### Check for overfiting

# %%
#Checking overfit for different epochs of training 
mean_mae_list_train_set = []
mean_mae_list_test_set = []
mean_mae_list_val_set = []

std_mae_list_train_set = []
std_mae_list_test_set = []
std_mae_list_val_set = []

for epochs_num in range(100,1900,100):
    mae_list_train_set = []
    mae_list_test_set = []
    mae_list_val_set = []
    
    for i in range(1,5,1):
        n_inputs, n_outputs = X_train.shape[1],1
        model_forward = get_model(n_inputs, n_outputs)
        print(epochs_num)
        # fit model
        model_forward.fit(X_train, y_train, verbose=0, epochs = epochs_num)

        # evaluate model on test set
        mae_list_train_set.append( model_forward.evaluate(X_train, y_train, verbose=0))
        mae_list_test_set.append( model_forward.evaluate(X_test, y_test, verbose=0) )
        #pred_2 = model.predict(df5[['h','top',	'base',	'wavelength']],df5['Reflectance'])
        mae_list_val_set.append(model_forward.evaluate(df5[['h','top',	'base',	'wavelength']], df5['Reflectance'], verbose=0))
    
    mean_mae_list_train_set.append( np.mean(mae_list_train_set))
    mean_mae_list_test_set.append( np.mean(mae_list_test_set))
    mean_mae_list_val_set.append( np.mean(mae_list_val_set))
    std_mae_list_train_set.append( np.std(mae_list_train_set))
    std_mae_list_test_set.append( np.std(mae_list_test_set))
    std_mae_list_val_set.append( np.std(mae_list_val_set))
    
#pred= model.predict(X_test,y_test)
# Out:
# 100
# 100
# 100
# 100
# 200
# 200
# 200
# 200
# 300
# 300
# 300
# 300
# 400
# 400
# 400
# 400
# 500
# 500
# 500
# 500
# 600
# 600
# 600
# 600
# 700
# 700
# 700
# 700
# 800
# 800
# 800
# 800
# 900
# 900
# 900
# 900
# 1000
# 1000
# 1000
# 1000
# 1100
# 1100
# 1100
# 1100
# 1200
# 1200
# 1200
# 1200
# 1300
# 1300
# 1300
# 1300
# 1400
# 1400
# 1400
# 1400
# 1500
# 1500
# 1500
# 1500
# 1600
# 1600
# 1600
# 1600
# 1700
# 1700
# 1700
# 1700
# 1800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-f15f006833a0> in <module>
#      18         print(epochs_num)
#      19         # fit model
# ---> 20         model_forward.fit(X_train, y_train, verbose=0, epochs = epochs_num)
#      21
#      22         # evaluate model on test set
#
# ...

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['mean_Final_RMSE'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
#ax1.legend(['mean_RMSE_percentage'],loc=2)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['training_rmse'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='black')
x_space = np.linspace(100, 2100, num=20)

line1 = ax1.errorbar(x_space,mean_mae_list_train_set, yerr=std_mae_list_train_set,ecolor='black',fmt='--^',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
ax1.legend(['train_set_mae'],loc=2)

line2 = ax1.errorbar(x_space,mean_mae_list_test_set, yerr=std_mae_list_test_set,ecolor='black',fmt='-*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='blue')
ax1.legend(['test_set_mae'],loc=2)

line2 = ax1.errorbar(x_space,mean_mae_list_val_set, yerr=std_mae_list_val_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='red')
ax1.legend(['heldout_set_mae'],loc=2)

#plt.legend(('mae_list_train', 'mae_list_test', 'mae_list_val'),
          # loc='upper center', shadow=True)
ylabel('Mean absolut error (mae)',fontsize=15)
plt.xlabel('Num of epochs (arb. units)',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Deep Neural Networks with 80% train set',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =500
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %%
#Overfit check with number of data for training

# %%
#Checking overfit for different epochs of training 
mean_mae_list_train_set = []
mean_mae_list_test_set = []
mean_mae_list_val_set = []

std_mae_list_train_set = []
std_mae_list_test_set = []
std_mae_list_val_set = []

n_epochs = 2000

for test_size_value in [0.05,0.1,0.15,0.20,0.25,0.30,0.35,0.40,0.45,0.50]:
    mae_list_train_set = []
    mae_list_test_set = []
    mae_list_val_set = []
    
    X_train, X_test, y_train, y_test = train_test_split(
    df4.drop(['Simulation index', 'Reflectance'], axis=1), # predictive variables
    df4['Reflectance'], # target
    test_size=0.2, # portion of dataset to allocate to test set
    random_state=0, # we are setting the seed here
        )
    print(test_size_value)
    for i in range(1,5,1):
        n_inputs, n_outputs = X_train.shape[1],1
        model_forward = get_model(n_inputs, n_outputs)
        #print(epochs_num)
        # fit model
        model_forward.fit(X_train, y_train, verbose=0, epochs = epochs_num)

        # evaluate model on test set
        mae_list_train_set.append( model_forward.evaluate(X_train, y_train, verbose=0))
        mae_list_test_set.append( model_forward.evaluate(X_test, y_test, verbose=0) )
        #pred_2 = model.predict(df5[['h','top',	'base',	'wavelength']],df5['Reflectance'])
        mae_list_val_set.append(model_forward.evaluate(df5[['h','top',	'base',	'wavelength']], df5['Reflectance'], verbose=0))
        del model_forward
        
    mean_mae_list_train_set.append( np.mean(mae_list_train_set))
    mean_mae_list_test_set.append( np.mean(mae_list_test_set))
    mean_mae_list_val_set.append( np.mean(mae_list_val_set))
    std_mae_list_train_set.append( np.std(mae_list_train_set))
    std_mae_list_test_set.append( np.std(mae_list_test_set))
    std_mae_list_val_set.append( np.std(mae_list_val_set))
    
#pred= model.predict(X_test,y_test)

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
x_space = [0.05,0.1,0.15,0.20,0.25,0.30,0.35,0.40,0.45,0.50]


line1 = ax1.errorbar(x_space,mean_mae_list_train_set, yerr=std_mae_list_train_set,ecolor='black',fmt='--^',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
ax1.legend(['train_set_mae'],loc=2)

line2 = ax1.errorbar(x_space,mean_mae_list_test_set, yerr=std_mae_list_test_set,ecolor='black',fmt='-*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='blue')
ax1.legend(['test_set_mae'],loc=2)

line2 = ax1.errorbar(x_space,mean_mae_list_val_set, yerr=std_mae_list_val_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='red')
ax1.legend(['heldout_set_mae'],loc=2)


ylabel('Mean absolut error (mae)',fontsize=15)
plt.xlabel('Test size ',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Deep Neural Networks with 2000 epochs',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =0.05
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %% [markdown]
# # Inverse problem

# %%
#Importing again the dataset 

#Add index simulation based on unique input values
df_col = df2.groupby(['h','top','base']).size().reset_index().rename(columns={0:'count'})
df3 = df2.reset_index().rename(columns = {'index': 'Simulation index'}, inplace = False)

i=1
for index, row in df_col.iterrows():
    df3.loc[(df3['h'] == row['h']) & (df3['top'] == row['top']) & (df3['base'] == row['base']),'Simulation index'] = i
    i+=1

# %%
#we need to reshape our data

# %%
scaler = MinMaxScaler()

df3[['h','top','base']] = scaler.fit_transform(df3[['h','top',	'base']])

# %%
#save min max scaler
import joblib
scaler_filename = "../minmaxscalers/inverse_scaler.save"
joblib.dump(scaler, scaler_filename) 
scaler = joblib.load(scaler_filename)

# %%
df3
# Out:
#       Simulation index    h  top  base  wavelength  Reflectance
# 0                    1  0.0  0.0   0.0  400.000000     0.044171
# 1                    1  0.0  0.0   0.0  403.030303     0.045151
# 2                    1  0.0  0.0   0.0  406.060606     0.046044
# 3                    1  0.0  0.0   0.0  409.090909     0.046886
# 4                    1  0.0  0.0   0.0  412.121212     0.047678
# ...                ...  ...  ...   ...         ...          ...
# 9995               100  1.0  1.0   1.0  687.878788     0.013585
# 9996               100  1.0  1.0   1.0  690.909091     0.013426
# 9997               100  1.0  1.0   1.0  693.939394     0.013271
# 9998               100  1.0  1.0   1.0  696.969697     0.013120
# 9999               100  1.0  1.0   1.0  700.000000     0.012974
#
# [10000 rows x 6 columns]

# %%
grouped_df = df3.groupby(['Simulation index','h','top','base'])
grouped_df = grouped_df.apply(lambda x: x['Reflectance'].unique())
grouped_df = grouped_df.to_frame().reset_index()
grouped_df = grouped_df.rename(columns= {0: 'Reflectance'})

# %%
grouped_df
# Out:
#     Simulation index    h  top      base  \
# 0                  1  0.0  0.0  0.000000
# 1                  2  0.0  0.0  0.138889
# 2                  3  0.0  0.0  0.277778
# 3                  4  0.0  0.0  0.416667
# 4                  5  0.0  0.0  0.555556
# ..               ...  ...  ...       ...
# 95                96  1.0  1.0  0.444444
# 96                97  1.0  1.0  0.583333
# 97                98  1.0  1.0  0.722222
# 98                99  1.0  1.0  0.861111
# 99               100  1.0  1.0  1.000000
#
#                                           Reflectance
# 0   [0.0441705845518706, 0.0451512878134928, 0.046...
# 1   [0.0396313691881517, 0.040764051987158, 0.0417...
# 2   [0.0345976283250554, 0.035954689964802, 0.0369...
# 3   [0.0294282118029957, 0.0310594583102924, 0.032...
# 4   [0.0244563302543115, 0.0263763566979613, 0.027...
# ..                                                ...
# 95  [0.0203499709151945, 0.0255063036653046, 0.028...
# ...

# %%
#Now we just make our train test set

# %%
X_train, X_test, y_train, y_test = train_test_split(
    grouped_df.drop(['Simulation index', 'h','top','base'], axis=1), # predictive variables
    grouped_df[['h','top','base']], # target
    test_size=0.2, # portion of dataset to allocate to test set
    random_state=1, # we are setting the seed here
)

X_train.shape, X_test.shape
# Out:
# ((80, 1), (20, 1))

# %%
y_test
# Out:
#            h   top      base
# 80  1.000000  0.25  0.111111
# 84  1.000000  0.25  0.666667
# 33  0.333333  0.25  0.527778
# 81  1.000000  0.25  0.250000
# 93  1.000000  0.75  0.750000
# 17  0.000000  0.75  0.611111
# 36  0.333333  0.50  0.361111
# 82  1.000000  0.25  0.388889
# 69  0.666667  0.75  0.888889
# 65  0.666667  0.75  0.333333
# 92  1.000000  0.75  0.611111
# 39  0.333333  0.50  0.777778
# 56  0.666667  0.25  0.250000
# 52  0.666667  0.00  0.277778
# 51  0.666667  0.00  0.138889
# 32  0.333333  0.25  0.388889
# 31  0.333333  0.25  0.250000
# 44  0.333333  0.75  0.888889
# 78  1.000000  0.00  0.416667
# 10  0.000000  0.50  0.222222

# %%
# get the model
def get_model(n_inputs, n_outputs):
    
	net1Model=keras.models.Sequential()
	net1Model.add(Dense(n_inputs))
	#net1Model.add(Activation('relu'))
	net1Model.add(Dense(240))
	net1Model.add(Activation('relu'))
	#net1Model.add(Dropout(0.5))
	net1Model.add(Dense(30))
	net1Model.add(Activation('relu'))
	#net1Model.add(Dropout(0.4))
#	net1Model.add(Dense(400))
#	net1Model.add(Dropout(0.6))
#	net1Model.add(Dense(400))
	#net1Model.add(Dropout(0.2))
	net1Model.add(Dense(1024))
    #net1Model.add(GaussianNoise(1.0))
	net1Model.add(Dense(n_outputs))
	net1Model.compile(optimizer='Adam',loss='mse')
    #net1Model.fit(X1, y1,epochs=1000,verbose=0)
	#model.compile(loss='mae', optimizer='adam')
    
	return net1Model

# %%
#new model
def get_model(n_inputs, n_outputs):
    
	net1Model=keras.models.Sequential()
	net1Model.add(Dense(n_inputs))
#	net1Model.add(Activation('relu'))
	net1Model.add(Dense(1024))
#	net1Model.add(Activation('relu'))
	net1Model.add(LeakyReLU(alpha=0.05))
	net1Model.add(Dense(240))
#	net1Model.add(Activation('relu'))
	net1Model.add(LeakyReLU(alpha=0.05))
	#net1Model.add(Dropout(0.5))
	net1Model.add(Dense(30))
#	net1Model.add(Activation('relu'))
	net1Model.add(LeakyReLU(alpha=0.05))
	#net1Model.add(Dropout(0.4))
#	net1Model.add(Dense(400))
#	net1Model.add(Dropout(0.6))
#	net1Model.add(Dense(400))
	#net1Model.add(Dropout(0.2))

    #net1Model.add(GaussianNoise(1.0))
	net1Model.add(Dense(n_outputs))
	net1Model.compile(optimizer='Adam',loss='mse')
    #net1Model.fit(X1, y1,epochs=1000,verbose=0)
	#model.compile(loss='mae', optimizer='adam')
    
	return net1Model

# %%
X_train.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.034598  0.035955  0.036998  0.037961  0.038867  0.039723  0.040530
# 1  0.012421  0.014287  0.014678  0.014773  0.014704  0.014524  0.014263
# 2  0.012848  0.014284  0.015563  0.016851  0.018161  0.019486  0.020797
# 3  0.019740  0.021466  0.021474  0.021267  0.020984  0.020663  0.020321
# 4  0.005392  0.007621  0.008907  0.010011  0.011030  0.012002  0.012938
#
#          7         8         9         10        11        12        13  \
# 0  0.041286  0.041992  0.042651  0.043265  0.043835  0.044362  0.044842
# 1  0.013948  0.013604  0.013261  0.012940  0.012647  0.012370  0.012088
# 2  0.022062  0.023265  0.024399  0.025464  0.026452  0.027352  0.028149
# 3  0.019973  0.019638  0.019334  0.019070  0.018843  0.018641  0.018450
# 4  0.013833  0.014680  0.015480  0.016246  0.016996  0.017744  0.018489
#
#          14        15        16        17        18        19        20  \
# ...

# %%
#spitted column
X_train = pd.DataFrame(X_train["Reflectance"].to_list())
X_test = pd.DataFrame(X_test["Reflectance"].to_list())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-dec3de7c4477> in <module>
#       1 #spitted column
# ----> 2 X_train = pd.DataFrame(X_train["Reflectance"].to_list())
#       3 X_test = pd.DataFrame(X_test["Reflectance"].to_list())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
# ...

# %%
n_inputs, n_outputs = X_train.shape[1],3
model = get_model(n_inputs, n_outputs)

# fit model
model.fit(X_train, y_train, verbose=0, epochs=1300)

# evaluate model on test set
#mae = model.evaluate(X_train, y_train, verbose=0)
mae = model.evaluate(X_test, y_test, verbose=1)

# %%
model.save('../models/model_inverse_v4_1300')

# %%
#save model to tf and tf lite form
import tensorflow as tf
from tensorflow import keras
#import keras tf model
model_inverse = '../models/model_inverse_v4_1300'
model = tf.keras.models.load_model(model_inverse)

#convert
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.target_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
converter.allow_custom_ops=True
converter.experimental_new_converter =True
tflite_model = converter.convert()
#Implement optimization strategy for smaller model sizes
#converter.optimizations = [tf.lite.Optimize.DEFAULT] #Uses default optimization strategy to reduce the model size

open('../models/model_inverse_v4_1300.tflite', "wb").write(tflite_model)

# %%
pred= model.predict(X_test)
df_pred = pd.DataFrame(data=pred, columns=['h','top','base'])
# Out:
# 1/1 [==============================] - 0s 50ms/step

# %%
df_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-ac2934792df8> in <module>
# ----> 1 df_pred
#
# NameError: name 'df_pred' is not defined

# %%
df_pred_inverse = scaler.inverse_transform(df_pred)

# %%
df_pred_inverse
# Out:
# array([[200.59842 ,  19.356739,  19.459951],
#        [200.94766 ,  21.22161 ,  68.66019 ],
#        [120.97029 ,  19.363865,  57.71868 ],
#        [201.32208 ,  19.519554,  31.838833],
#        [202.2751  ,  41.334305,  77.2151  ],
#        [ 80.67268 ,  39.99821 ,  62.89578 ],
#        [120.70126 ,  29.54329 ,  42.478508],
#        [201.52007 ,  19.969767,  45.66256 ],
#        [159.57957 ,  41.55007 ,  90.05506 ],
#        [163.1785  ,  40.463516,  40.150864],
#        [201.94708 ,  41.471485,  62.891037],
#        [118.9886  ,  30.931463,  77.12798 ],
#        [160.83733 ,  21.3354  ,  34.761223],
#        [162.18509 ,  12.233704,  37.938263],
#        [160.70438 ,  12.809128,  21.054462],
#        [120.82875 ,  19.216328,  44.86354 ],
#        [120.11484 ,  19.608307,  31.735977],
#        [119.357605,  41.055145,  88.992874],
#        [201.2763  ,  11.37542 ,  48.65908 ],
#        [ 80.74206 ,  30.57507 ,  31.89646 ]], dtype=float32)

# %%
df_pred_inverse = scaler.inverse_transform(df_pred)
df_test_inverse = scaler.inverse_transform(y_test)

# %%
df_pred_inverse = pd.DataFrame(data=df_pred_inverse, columns=['h','top','base'])
df_test_inverse = pd.DataFrame(data=df_test_inverse, columns=['h','top','base'])

# %%
df_test_inverse
# Out:
#         h   top  base
# 0   200.0  20.0  20.0
# 1   200.0  20.0  70.0
# 2   120.0  20.0  57.5
# 3   200.0  20.0  32.5
# 4   200.0  40.0  77.5
# 5    80.0  40.0  65.0
# 6   120.0  30.0  42.5
# 7   200.0  20.0  45.0
# 8   160.0  40.0  90.0
# 9   160.0  40.0  40.0
# 10  200.0  40.0  65.0
# 11  120.0  30.0  80.0
# 12  160.0  20.0  32.5
# 13  160.0  10.0  35.0
# 14  160.0  10.0  22.5
# 15  120.0  20.0  45.0
# 16  120.0  20.0  32.5
# 17  120.0  40.0  90.0
# 18  200.0  10.0  47.5
# 19   80.0  30.0  30.0

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred_inverse['h'],df_test_inverse['h'],alpha=0.6,s=20)
plt.plot([80, 200],[80, 200],'r',alpha=0.9)
plt.ylabel('True H (nm)',fontsize=15)
plt.xlabel('Predicted H (nm)',fontsize=15)
plt.title('Deep Neural Network Height Prediction (inverse) ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([70, 210])
plt.ylim([70, 210])

plt.show()

mean_absolute_error(df_pred_inverse['h'],df_test_inverse['h'])
# Out:
# 1.1448055267334083

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred['h'],y_test['h'],alpha=0.6,s=20)
plt.plot([0, 1],[0, 1],'r',alpha=0.9)
plt.ylabel('True H (nm)',fontsize=15)
plt.xlabel('Predicted H (nm) ',fontsize=15)
plt.title('Deep Neural Network ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([-0.05, 1.1])
plt.ylim([-0.05, 1.1])

plt.show()
mean_absolute_error(df_pred['h'],y_test['h'])
# Out:
# 0.010157373081892735

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred_inverse['top'],df_test_inverse['top'],alpha=0.6,s=20)
plt.plot([10, 50],[10, 50],'r',alpha=0.9)
plt.ylabel('True top (nm)',fontsize=15)
plt.xlabel('Predicted top (nm) ',fontsize=15)
plt.title('Deep Neural Network Top Prediction (inverse) ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([5, 55])
plt.ylim([5, 55])

plt.show()

mean_absolute_error(df_pred_inverse['top'],df_test_inverse['top'])
# Out:
# 1.5270871639251709

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred['top'],y_test['top'],alpha=0.6,s=20)
plt.plot([0, 1],[0, 1],'r',alpha=0.9)
plt.ylabel('True top',fontsize=15)
plt.xlabel('Predicted top ',fontsize=15)
plt.title('Deep Neural Network ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([-0.05, 1.1])
plt.ylim([-0.05, 1.1])

plt.show()
mean_absolute_error(df_pred['top'],y_test['top'])
# Out:
# 0.038177175587043165

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred_inverse['base'],df_test_inverse['base'],alpha=0.6,s=20)
plt.plot([10, 100],[10, 100],'r',alpha=0.9)
plt.ylabel('True base (nm)',fontsize=15)
plt.xlabel('Predicted base (nm) ',fontsize=15)
plt.title('Deep Neural Network Base Prediction (inverse) ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([5, 105])
plt.ylim([5, 105])

plt.show()
mean_absolute_error(df_pred_inverse['base'],df_test_inverse['base'])
# Out:
# 1.7618646621704102

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred['base'],y_test['base'],alpha=0.6,s=20)
plt.plot([0, 1],[0, 1],'r',alpha=0.9)
plt.ylabel('True base',fontsize=15)
plt.xlabel('Predicted base ',fontsize=15)
plt.title('Deep Neural Network ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([-0.05, 1.1])
plt.ylim([-0.05, 1.1])

plt.show()
mean_absolute_error(df_pred['base'],y_test['base'])
# Out:
# 0.019576274851957946

# %%
pred= model.predict(X_train)
df_pred = pd.DataFrame(data=pred, columns=['h','top','base'])

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred['h'],y_train['h'],alpha=0.6,s=20)
plt.plot([0, 1],[0, 1],'r',alpha=0.9)
plt.ylabel('True scaled H',fontsize=15)
plt.xlabel('Predicted  scaled H',fontsize=15)
plt.title('Deep Neural Network (Test size= 22%)',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([-0.05, 1])
plt.ylim([-0.05, 1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-34f8d2cf47f6> in <module>
#       1 plt.figure(figsize=(9,7))
# ----> 2 plt.scatter(df_pred['h'],y_train['h'],alpha=0.6,s=20)
#       3 plt.plot([0, 1],[0, 1],'r',alpha=0.9)
#       4 plt.ylabel('True scaled H',fontsize=15)
#       5 plt.xlabel('Predicted  scaled H',fontsize=15)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred['top'],y_train['top'],alpha=0.6,s=20)
plt.plot([0, 60],[0, 60],'r',alpha=0.9)
plt.ylabel('True top',fontsize=15)
plt.xlabel('Predicted top ',fontsize=15)
plt.title('Deep Neural Network (Test size= 22%)',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([-0.05, 1])
plt.ylim([-0.05, 1])

plt.show()

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred['base'],y_train['base'],alpha=0.6,s=20)
plt.plot([0, 50],[0, 50],'r',alpha=0.9)
plt.ylabel('True base',fontsize=15)
plt.xlabel('Predicted base ',fontsize=15)
plt.title('Deep Neural Network (Test size= 22%)',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([-0.05, 1])
plt.ylim([-0.05, 1])
plt.show()

# %%
df_pred
# Out:
#            h       top      base
# 0   0.004424  0.022821  0.254295
# 1   0.662745  0.982163  0.864372
# 2   1.013058  0.981705  0.707407
# 3   0.668498  0.489520  0.504244
# 4   0.010791  0.746020  0.881950
# ..       ...       ...       ...
# 75  1.016271 -0.011245  0.002592
# 76  0.004061  0.260922  0.658542
# 77  0.668619  0.977864  0.713535
# 78 -0.003360  0.493515  0.495248
# 79  0.342602  0.473685  0.506253
#
# [80 rows x 3 columns]

# %%
#Inverse the transformation of the predicted features

# %%
df_pred_inverse = scaler.inverse_transform(df_pred)

# %%
df_test_inverse = scaler.inverse_transform(y_test)

# %% [markdown]
# ### Check for overfiting

# %% [markdown]
# #### For different epochs

# %%
#Checking overfit for different epochs of training 
mae_list_train_set = []
mae_list_test_set = []

for epochs_num in range(100,2100,100):
    n_inputs, n_outputs = X_train.shape[1],3
    model = get_model(n_inputs, n_outputs)
    print(epochs_num)
    # fit model
    model.fit(X_train, y_train, verbose=0, epochs = epochs_num)

    # evaluate model on test set
    mae_list_train_set.append( model.evaluate(X_train, y_train, verbose=0))
    mae_list_test_set.append( model.evaluate(X_test, y_test, verbose=0) )
    
    #for the subplot error
    
    df_pred = pd.DataFrame(data=pred, columns=['h','top','base'])
    
    
    del model
    #pred_2 = model.predict(df5[['h','top',	'base',	'wavelength']],df5['Reflectance'])
    #mae_list_val_set.append(model.evaluate(df5[['h','top',	'base',	'wavelength']], df5['Reflectance'], verbose=0))
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000

# %%
model.evaluate(X_train, y_train, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-c00e29d223e0> in <module>
# ----> 1 model.evaluate(X_train, y_train, verbose=0)
#
# NameError: name 'model' is not defined

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['mean_Final_RMSE'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
#ax1.legend(['mean_RMSE_percentage'],loc=2)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['training_rmse'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='black')
plt.plot(np.linspace(100, 2100, num=20), mae_list_train_set, '--g^')
plt.plot(np.linspace(100, 2100, num=20), mae_list_test_set, '-b*')
#plt.plot(np.linspace(100, 2100, num=20), mae_list_val_set, '--r*')
plt.legend(('mae_list_train', 'mae_list_test', 'mae_list_val'),
           loc='upper center', shadow=True)
ylabel('Mean absolut error (mae)',fontsize=15)
plt.xlabel('Epochs of training (arb. units)',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Neural Networks, Inverse problem',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =500
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['mean_Final_RMSE'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
#ax1.legend(['mean_RMSE_percentage'],loc=2)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['training_rmse'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='black')
plt.plot(np.linspace(100, 2100, num=20), mae_list_train_set, '--g^')
plt.plot(np.linspace(100, 2100, num=20), mae_list_test_set, '-b*')
#plt.plot(np.linspace(100, 2100, num=20), mae_list_val_set, '--r*')
plt.legend(('mae_list_train', 'mae_list_test', 'mae_list_val'),
           loc='upper center', shadow=True)
ylabel('Mean absolut error (mae)',fontsize=15)
plt.xlabel('Epochs of training (arb. units)',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Neural Networks, Inverse problem',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =500
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')
plt.xlim([500, 2200])
plt.ylim([-0.002,  0.005])
#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %% [markdown]
# #### For different train sizes

# %%
#Checking overfit for different epochs of training 
mean_mae_list_train_set = []
mean_mae_list_test_set = []
std_mae_list_train_set = []
std_mae_list_test_set = []
for test_size_value in [0.05,0.1,0.15,0.20,0.25,0.30,0.35,0.40,0.45,0.50]:
    mean_mae_train = []
    mean_mae_test = []
    print(test_size_value)
    for i in range(1,20,1):
        X_train, X_test, y_train, y_test = train_test_split(
        grouped_df.drop(['Simulation index', 'h','top','base'], axis=1), # predictive variables
        grouped_df[['h','top','base']], # target
        test_size = test_size_value, # portion of dataset to allocate to test set
        random_state=0, # we are setting the seed here
        )
        
        #transform onecolumn dataframe to num of values in least sized dataframe
        X_train = pd.DataFrame(X_train["Reflectance"].to_list())
        X_test = pd.DataFrame(X_test["Reflectance"].to_list())

        n_inputs, n_outputs = X_train.shape[1],3
        model = get_model(n_inputs, n_outputs)
        
        # fit model
        model.fit(X_train, y_train, verbose=0, epochs = 2000)
        
        mean_mae_train.append( model.evaluate(X_train, y_train, verbose=0))
        mean_mae_test.append( model.evaluate(X_test, y_test, verbose=0) )
        

    # evaluate model on test set
    mean_mae_list_train_set.append(np.mean(mean_mae_train))
    mean_mae_list_test_set.append(np.mean(mean_mae_test))
    
    std_mae_list_train_set.append(np.std(mean_mae_train))
    std_mae_list_test_set.append(np.std(mean_mae_test))
    #for the subplot error
    
    df_pred = pd.DataFrame(data=pred, columns=['h','top','base'])
    
    
    del model
    #pred_2 = model.predict(df5[['h','top',	'base',	'wavelength']],df5['Reflectance'])
    #mae_list_val_set.append(model.evaluate(df5[['h','top',	'base',	'wavelength']], df5['Reflectance'], verbose=0))
# Out:
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
x_space = [0.05,0.1,0.15,0.20,0.25,0.30,0.35,0.40,0.45,0.50]
line1 = ax1.errorbar(x_space,mean_mae_list_train_set, yerr=std_mae_list_train_set,ecolor='black',fmt='--^',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
ax1.legend(['mean_RMSE_percentage'],loc=2)
line1 = ax1.errorbar(x_space,mean_mae_list_test_set, yerr=std_mae_list_test_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='black')

#plt.plot(x_space, mean_mae_list_train_set, '--g^')
#plt.plot(x_space, mean_mae_list_test_set, '-b*')
#plt.plot(np.linspace(100, 2100, num=20), mae_list_val_set, '--r*')
plt.legend(('mae_list_train', 'mae_list_test'),
           loc='upper center', shadow=True)
ylabel('Mean absolut error (mae)',fontsize=15)
plt.xlabel('Test size ',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Neural Networks, Inverse problem',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =0.05
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %%
#subplot different features errors

# %% [markdown]
# ### Action points

# %% [markdown]
# **Forward problem**
# * Max error
# * Error for other spectra
# * Error vs training size
# * -> look up table
#
#
# **Inverse problem**
# * Overfiting search
# *
# *
#
# -> spectrum -> (fowrad)-> Features ->(Inverse) -> Spectrum

# %%
#choose a spectrum
Simulation_ind = 40
grouped_df[grouped_df['Simulation index'] == Simulation_ind]
# Out:
#     Simulation index         h  top      base  \
# 39                40  0.333333  0.5  0.777778
#
#                                           Reflectance
# 39  [0.0136327992003718, 0.0159041458823391, 0.016...

# %%
h,top,base = model.predict(pd.DataFrame(grouped_df[grouped_df['Simulation index'] == Simulation_ind]["Reflectance"].to_list()))[0]
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
h,top,base
# Out:
# (0.29641682, 0.56406605, 0.72360665)

# %%
df_helout = df3[df3['Simulation index'] == Simulation_ind]

# %%
df_helout['h'] = h
df_helout['top'] = top
df_helout['base'] = base
# Out:
# <ipython-input-96-fbf38d84c6e2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_helout['h'] = h
# <ipython-input-96-fbf38d84c6e2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_helout['top'] = top
# <ipython-input-96-fbf38d84c6e2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_helout.head()
# Out:
#       Simulation index         h       top      base  wavelength  Reflectance
# 3900                40  0.296417  0.564066  0.723607  400.000000     0.013633
# 3901                40  0.296417  0.564066  0.723607  403.030303     0.015904
# 3902                40  0.296417  0.564066  0.723607  406.060606     0.016310
# 3903                40  0.296417  0.564066  0.723607  409.090909     0.016411
# 3904                40  0.296417  0.564066  0.723607  412.121212     0.016381

# %%
#39

pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()

# %%
#40

pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()

# %%
#40

pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

#plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()

# %%
#41

pre_heldout= model_forward.predict(df_helout.drop(['Simulation index', 'Reflectance'], axis=1))

plt.plot(df_helout['wavelength'], pre_heldout, 'r') # plotting t, a separately 
plt.plot(df_helout['wavelength'], df_helout['Reflectance'], 'b') # plotting t, b separately 
plt.show()

# %% [markdown]
# ### Testing model with data from additional runs (out of the feature gradings)

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("data/Test model data/extra_11.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

# %%
df_test_out
# Out:
#                h           top          base  wavelength  Reflectance
# 0   1.200000e-07  3.000000e-08  5.000000e-08    0.400000     0.013633
# 1   1.200000e-07  3.000000e-08  5.000000e-08    0.403030     0.015904
# 2   1.200000e-07  3.000000e-08  5.000000e-08    0.406061     0.016310
# 3   1.200000e-07  3.000000e-08  5.000000e-08    0.409091     0.016411
# 4   1.200000e-07  3.000000e-08  5.000000e-08    0.412121     0.016381
# ..           ...           ...           ...         ...          ...
# 95  1.200000e-07  3.000000e-08  5.000000e-08    0.687879     0.013889
# 96  1.200000e-07  3.000000e-08  5.000000e-08    0.690909     0.014151
# 97  1.200000e-07  3.000000e-08  5.000000e-08    0.693939     0.014414
# 98  1.200000e-07  3.000000e-08  5.000000e-08    0.696970     0.014680
# 99  1.200000e-07  3.000000e-08  5.000000e-08    0.700000     0.014947
#
# [100 rows x 5 columns]

# %%
#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']

# %%
df_test_out
# Out:
#         h   top  base  wavelength  Reflectance
# 0   120.0  30.0  80.0  400.000000     0.013633
# 1   120.0  30.0  80.0  403.030303     0.015904
# 2   120.0  30.0  80.0  406.060606     0.016310
# 3   120.0  30.0  80.0  409.090909     0.016411
# 4   120.0  30.0  80.0  412.121212     0.016381
# ..    ...   ...   ...         ...          ...
# 95  120.0  30.0  80.0  687.878788     0.013889
# 96  120.0  30.0  80.0  690.909091     0.014151
# 97  120.0  30.0  80.0  693.939394     0.014414
# 98  120.0  30.0  80.0  696.969697     0.014680
# 99  120.0  30.0  80.0  700.000000     0.014947
#
# [100 rows x 5 columns]

# %%
# Forward predict test

# %%
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

# %%
pre_heldout= model_forward.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
#os.chdir("data/Test model data")

frames = []
for file in glob.glob("*.txt"):

    df_test_out = pd.read_csv(file, sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])
    #convert to nanometers:
    df_test_out['h'] = df_test_out['h']* 10**9
    df_test_out['top'] = df_test_out['top']* 10**9
    df_test_out['base'] = df_test_out['base']* 10**9
    df_test_out['wavelength'] = df_test_out['wavelength']* 10**3
    df_test_out['wavelength'] = df_test_out['wavelength']* 10**3
    frames.append(df_test_out)
    
extra_df = pd.concat(frames)

# %% [markdown]
# ### Inverse test

# %%
# add all data together

# %%
#(data is distributed in different txts. Here we add them all together)
#read the data with pandas and convert to a dataframe
#os.chdir("data/Test model data")

frames = []
for file in glob.glob("*.txt"):

    df_test_out = pd.read_csv(file, sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])
    #convert to nanometers:
    df_test_out['h'] = df_test_out['h']* 10**9
    df_test_out['top'] = df_test_out['top']* 10**9
    df_test_out['base'] = df_test_out['base']* 10**9
    df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

    df_test_out['base'] = df_test_out['base'] + df_test_out['top']
    frames.append(df_test_out)

# %%
extra_df = pd.concat(frames)

# %%
extra_df = extra_df.groupby(['h','top','base'])
extra_df = extra_df.apply(lambda x: x['Reflectance'].unique())
extra_df = extra_df.reset_index()
extra_df = extra_df.rename(columns= {0: 'Reflectance'})

# %%
extra_df =extra_df.drop(extra_df.index[[0]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-34f4390cd479> in <module>
# ----> 1 extra_df =extra_df.drop(extra_df.index[[0]])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in __getitem__(self, key)
#     778             )
#     779         # fall back to Int64Index
# --> 780         return super().__getitem__(key)
#     781
#     782     @unpack_zerodim_and_defer("__floordiv__")
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4305             key = np.asarray(key, dtype=bool)
#    4306
# -> 4307         result = getitem(key)
#    4308         if not is_scalar(result):
#    4309             if np.ndim(result) > 1:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
extra_X_test = pd.DataFrame(extra_df['Reflectance'].to_list())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Reflectance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-f049236c3075> in <module>
# ...

# %%
pred= model.predict(extra_X_test)

# %%
pred
# Out:
# array([[ 0.32989305,  0.38853443,  0.61667204],
#        [ 0.33719823,  0.5192367 ,  0.7740561 ],
#        [ 0.47802973,  0.43685198,  0.37065578],
#        [ 0.55116427,  0.8670133 ,  0.5481683 ],
#        [ 0.6914215 ,  1.1853894 ,  1.0175442 ],
#        [ 0.97166485, -0.10176811,  0.43347022],
#        [ 0.99795145,  0.29002786,  0.52170306],
#        [ 1.050164  , -0.11748607,  0.20501813],
#        [ 1.0485924 ,  0.9267698 ,  0.42683575]], dtype=float32)

# %%
df_pred_inverse = pd.DataFrame(data=pred, columns=['h','top','base'])
df_pred_inverse = scaler.inverse_transform(df_pred_inverse)
df_pred_inverse = pd.DataFrame(data=df_pred_inverse, columns=['h','top','base'])

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred_inverse['h'],extra_df.reset_index()['h'],alpha=0.6,s=20)
plt.plot([80, 200],[80, 200],'r',alpha=0.9)
plt.ylabel('True H (nm)',fontsize=15)
plt.xlabel('Predicted H (nm)',fontsize=15)
plt.title('Deep Neural Network Height Prediction (inverse) ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([70, 220])
plt.ylim([70, 220])

plt.show()

print(mean_absolute_error(df_pred_inverse['h'],extra_df.reset_index()['h']))
print(mean_absolute_error(df_pred_inverse['h'],extra_df.reset_index()['h'])/mean(extra_df.reset_index()['h']))
# Out:
# 7.5623118082682135
# 0.04680935782284313

# %%
df_pred_inverse['h']
# Out:
# 0    119.587166
# 1    120.463783
# 2    137.363556
# 3    146.139709
# 4    162.970581
# 5    196.599777
# 6    199.754181
# 7    206.019669
# 8    205.831085
# Name: h, dtype: float32

# %%
extra_df.reset_index()['h']
# Out:
# 0    115.0
# 1    120.0
# 2    142.0
# 3    151.0
# 4    160.0
# 5    182.0
# 6    182.0
# 7    192.0
# 8    210.0
# Name: h, dtype: float64

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred_inverse['top'],extra_df.reset_index()['top'],alpha=0.6,s=20)
plt.plot([10,59],[10, 59],'r',alpha=0.9)
plt.ylabel('True top (nm)',fontsize=15)
plt.xlabel('Predicted top (nm) ',fontsize=15)
plt.title('Deep Neural Network Top Prediction (inverse) ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([0, 60])
plt.ylim([0, 60])

plt.show()

print(mean_absolute_error(df_pred_inverse['top'],extra_df.reset_index()['top']))
print(mean_absolute_error(df_pred_inverse['top'],extra_df.reset_index()['top'])/mean(extra_df.reset_index()['top']))
# Out:
# 5.306646241082086
# 0.16996375861117

# %%
mean_absolute_error(df_pred_inverse['top'],extra_df.reset_index()['top'])/mean(extra_df.reset_index()['top'])
# Out:
# 0.16996375861117

# %%
plt.figure(figsize=(9,7))
plt.scatter(df_pred_inverse['base'],extra_df.reset_index()['base'],alpha=0.6,s=20)
plt.plot([10, 100],[10, 100],'r',alpha=0.9)
plt.ylabel('True base (nm)',fontsize=15)
plt.xlabel('Predicted base (nm) ',fontsize=15)
plt.title('Deep Neural Network Base Prediction (inverse) ',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([5, 105])
plt.ylim([5, 105])

plt.show()
print(mean_absolute_error(df_pred_inverse['base'],extra_df.reset_index()['base']))
print(mean_absolute_error(df_pred_inverse['base'],extra_df.reset_index()['base'])/mean(extra_df.reset_index()['base']))
# Out:
# 3.6181481679280605
# 0.062381864964276904

# %%
df_pred_inverse['base']
# Out:
# 0     65.500481
# 1     79.665047
# 2     43.359020
# 3     59.335148
# 4    101.578979
# 5     49.012321
# 6     56.953274
# 7     28.451632
# 8     48.415218
# Name: base, dtype: float32

# %% [markdown]
# #### Inverse problem: How does the model performs depending on its epochs and the size of data vs the error of the heldout_extra data?

# %% [markdown]
# Epoch dependance

# %%
extra_X_test.head(2)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.020080  0.022062  0.022448  0.022579  0.022599  0.022547  0.022437
# 1  0.013633  0.015904  0.016310  0.016411  0.016381  0.016274  0.016109
#
#          7         8         9         10        11        12        13  \
# 0  0.022273  0.022066  0.021833  0.021595  0.021366  0.021146  0.020927
# 1  0.015891  0.015630  0.015346  0.015065  0.014804  0.014566  0.014343
#
#          14        15        16        17        18        19        20  \
# 0  0.020697  0.020446  0.020172  0.019882  0.019590  0.019309  0.019046
# 1  0.014116  0.013874  0.013610  0.013331  0.013053  0.012793  0.012562
#
#          21        22        23        24        25        26        27  \
# 0  0.018800  0.018562  0.018324  0.018077  0.017819  0.017555  0.017296
# 1  0.012357  0.012169  0.011984  0.011792  0.011587  0.011374  0.011164
#
#          28        29        30        31        32        33        34  \
# ...

# %%
#All the inverse code we wrote again here all together:

#Add index simulation based on unique input values
df_col = df2.groupby(['h','top','base']).size().reset_index().rename(columns={0:'count'})
df3 = df2.reset_index().rename(columns = {'index': 'Simulation index'}, inplace = False)

i=1
for index, row in df_col.iterrows():
    df3.loc[(df3['h'] == row['h']) & (df3['top'] == row['top']) & (df3['base'] == row['base']),'Simulation index'] = i
    i+=1

scaler = MinMaxScaler()

df3[['h','top','base']] = scaler.fit_transform(df3[['h','top',	'base']])

grouped_df = df3.groupby(['Simulation index','h','top','base'])
grouped_df = grouped_df.apply(lambda x: x['Reflectance'].unique())
grouped_df = grouped_df.to_frame().reset_index()
grouped_df = grouped_df.rename(columns= {0: 'Reflectance'})


X_train, X_test, y_train, y_test = train_test_split(
    grouped_df.drop(['Simulation index', 'h','top','base'], axis=1), # predictive variables
    grouped_df[['h','top','base']], # target
    test_size=0.2, # portion of dataset to allocate to test set
    random_state=1, # we are setting the seed here
)

X_train.shape, X_test.shape

# get the model
def get_model(n_inputs, n_outputs):
    
	net1Model=keras.models.Sequential()
	net1Model.add(Dense(n_inputs))
	#net1Model.add(Activation('relu'))
	net1Model.add(Dense(240))
	net1Model.add(Activation('relu'))
	#net1Model.add(Dropout(0.5))
	net1Model.add(Dense(30))
	net1Model.add(Activation('relu'))
	#net1Model.add(Dropout(0.4))
#	net1Model.add(Dense(400))
#	net1Model.add(Dropout(0.6))
#	net1Model.add(Dense(400))
	#net1Model.add(Dropout(0.2))
	net1Model.add(Dense(1024))
    #net1Model.add(GaussianNoise(1.0))
	net1Model.add(Dense(n_outputs))
	net1Model.compile(optimizer='Adam',loss='mse')
    #net1Model.fit(X1, y1,epochs=1000,verbose=0)
    #model.compile(loss='mae', optimizer='adam')
    
	return net1Model

#spitted column
X_train = pd.DataFrame(X_train["Reflectance"].to_list())
X_test = pd.DataFrame(X_test["Reflectance"].to_list())

# %%
extra_df[['h','top', 'base']]

extra_df_transformed = scaler.transform(extra_df[['h','top', 'base']])
extra_df_transformed = pd.DataFrame(data=extra_df_transformed, columns=['h','top','base'])

# %%
#Checking Error rate for different epochs of training 
mean_mae_list_train_set = []
mean_mae_list_test_set = []
mean_mae_list_extra_set = []
    
std_mae_list_train_set = []
std_mae_list_test_set = []
std_mae_list_extra_set = []

for epochs_num in range(100,2100,100):
    print(epochs_num)
    mae_list_train_set = []
    mae_list_test_set = []
    mae_list_extra_set = []
    
    for i in range(1,5,1):
        n_inputs, n_outputs = X_train.shape[1],3
        model = get_model(n_inputs, n_outputs)
        

        # fit model
        model.fit(X_train, y_train, verbose=0, epochs = epochs_num)

        # evaluate model on test set
        mae_list_train_set.append( model.evaluate(X_train, y_train, verbose=0))
        mae_list_test_set.append( model.evaluate(X_test, y_test, verbose=0) )
        mae_list_extra_set.append( model.evaluate(extra_X_test, extra_df_transformed, verbose=0) )
        #for the subplot error
        #df_pred = pd.DataFrame(data=pred, columns=['h','top','base'])


        del model
    mean_mae_list_train_set.append(np.mean(mae_list_train_set))
    mean_mae_list_test_set.append(np.mean(mae_list_test_set))
    mean_mae_list_extra_set.append(np.mean(mae_list_extra_set))
    
    std_mae_list_train_set.append(np.std(mae_list_train_set))
    std_mae_list_test_set.append(np.std(mae_list_test_set))
    std_mae_list_extra_set.append(np.std(mae_list_extra_set))    
    #pred_2 = model.predict(df5[['h','top', 'base', 'wavelength']],df5['Reflectance'])
    #mae_list_val_set.append(model.evaluate(df5[['h','top', 'base', 'wavelength']], df5['Reflectance'], verbose=0))
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
line1 = ax1.errorbar(np.linspace(100, 2100, num=20),mean_mae_list_train_set, yerr=std_mae_list_train_set,ecolor='black',fmt='--^',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
#ax1.legend(['mean_RMSE_percentage'],loc=2)
line2 = ax1.errorbar(np.linspace(100, 2100, num=20),mean_mae_list_test_set, yerr=std_mae_list_test_set,ecolor='black',fmt='-*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='blue')

line3 = ax1.errorbar(np.linspace(100, 2100, num=20),mean_mae_list_extra_set, yerr=std_mae_list_extra_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='red')
#plt.plot(np.linspace(100, 2100, num=10), mae_list_train_set, '--g^')
#plt.plot(np.linspace(100, 2100, num=10), mae_list_test_set, '-b*')
#plt.plot(np.linspace(100, 2100, num=10), mae_list_extra_set, '--r*')
#plt.plot(np.linspace(100, 2100, num=20), mae_list_val_set, '--r*')
plt.legend(('mae_list_train', 'mae_list_test', 'mae_list_val'),
           loc='upper center', shadow=True)
ylabel('Mean absolut error (mae)',fontsize=15)
plt.xlabel('Epochs of training (arb. units)',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Neural Networks, Inverse problem',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =500
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %% [markdown]
# Train size dependance

# %%
#Checking overfit for different epochs of training 
mean_mae_list_train_set = []
mean_mae_list_test_set = []
mean_mae_list_extra_set = []

std_mae_list_train_set = []
std_mae_list_test_set = []
std_mae_list_extra_set = []


for test_size_value in [0.05,0.1,0.15,0.20,0.25,0.30,0.35,0.40,0.45,0.50,0.55,0.6,0.65,0.70,0.75,0.80]:
    mean_mae_train = []
    mean_mae_test = []
    mean_mae_extra = []
    print(test_size_value)
    for i in range(1,7,1):
        X_train, X_test, y_train, y_test = train_test_split(
        grouped_df.drop(['Simulation index', 'h','top','base'], axis=1), # predictive variables
        grouped_df[['h','top','base']], # target
        test_size = test_size_value, # portion of dataset to allocate to test set
        random_state=0, # we are setting the seed here
        )
        
        #transform onecolumn dataframe to num of values in least sized dataframe
        X_train = pd.DataFrame(X_train["Reflectance"].to_list())
        X_test = pd.DataFrame(X_test["Reflectance"].to_list())

        n_inputs, n_outputs = X_train.shape[1],3
        model = get_model(n_inputs, n_outputs)
        
        # fit model
        model.fit(X_train, y_train, verbose=0, epochs = 700)
        
        mean_mae_train.append( model.evaluate(X_train, y_train, verbose=0))
        mean_mae_test.append( model.evaluate(X_test, y_test, verbose=0) )
        mean_mae_extra.append( model.evaluate(extra_X_test, extra_df_transformed, verbose=0) )

    # evaluate model on test set
    mean_mae_list_train_set.append(np.mean(mean_mae_train))
    mean_mae_list_test_set.append(np.mean(mean_mae_test))
    mean_mae_list_extra_set.append(np.mean(mean_mae_extra))
    
    std_mae_list_train_set.append(np.std(mean_mae_train))
    std_mae_list_test_set.append(np.std(mean_mae_test))
    std_mae_list_extra_set.append(np.std(mean_mae_extra))
    #for the subplot error
    
    #df_pred = pd.DataFrame(data=pred, columns=['h','top','base'])
    
    
    del model
    #pred_2 = model.predict(df5[['h','top',	'base',	'wavelength']],df5['Reflectance'])
    #mae_list_val_set.append(model.evaluate(df5[['h','top',	'base',	'wavelength']], df5['Reflectance'], verbose=0))
# Out:
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6
# 0.65
# 0.7
# 0.75
# 0.8

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
x_space = [0.05,0.1,0.15,0.20,0.25,0.30,0.35,0.40,0.45,0.50,0.55,0.6,0.65,0.70,0.75,0.80]
line1 = ax1.errorbar(x_space,mean_mae_list_train_set, yerr=std_mae_list_train_set,ecolor='black',fmt='--^',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
#ax1.legend(['mean_RMSE_percentage'],loc=2)
line2 = ax1.errorbar(x_space,mean_mae_list_test_set, yerr=std_mae_list_test_set,ecolor='black',fmt='-*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='blue')

line3 = ax1.errorbar(x_space,mean_mae_list_extra_set, yerr=std_mae_list_extra_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='red')
#plt.plot(np.linspace(100, 2100, num=10), mae_list_train_set, '--g^')
#plt.plot(np.linspace(100, 2100, num=10), mae_list_test_set, '-b*')
#plt.plot(np.linspace(100, 2100, num=10), mae_list_extra_set, '--r*')
#plt.plot(np.linspace(100, 2100, num=20), mae_list_val_set, '--r*')
plt.legend(('mae_list_train', 'mae_list_test', 'mae_list_val'),
           loc='upper center', shadow=True)
ylabel('Mean absolut error (mae)',fontsize=15)
plt.xlabel('test size (arb. units)',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Neural Networks, Inverse problem',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =0.05
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %% [markdown]
# Nxt steps:
# * Check for the points that have high errors. What h, top, base they have?
# * Συζήτηση για SPIE

# %% [markdown]
# ## Forward problem check for overfit and performance

# %%
# read external data with pandas and convert to a dataframe (data is distributed in different txts. Here we add them all together)
#os.chdir("data/Test model data")

frames = []
i= 100
for file in glob.glob("*.txt"):

    df_test_out = pd.read_csv(file, sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])
    #convert to nanometers:
    df_test_out['h'] = df_test_out['h']* 10**9
    df_test_out['top'] = df_test_out['top']* 10**9
    df_test_out['base'] = df_test_out['base']* 10**9
    df_test_out['wavelength'] = df_test_out['wavelength']* 10**3
    df_test_out['wavelength'] = df_test_out['wavelength']* 10**3
    df_test_out['Simulation index'] = i
    frames.append(df_test_out)
    i = i + 1
    
    
#concat all the frames to get one dataframe:
extra_df = pd.concat(frames)

# %%
#visulize plots

# %%
a4_dims = (8, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.lineplot(ax=ax,data=extra_df, x="wavelength", y='Reflectance',hue = "Simulation index")
plt.ylabel('Reflectivity',fontsize=12)
plt.xlabel('Wavelength (nm)',fontsize=12)
# Out:
# Text(0.5, 0, 'Wavelength (nm)')

# %%
#requirement: extra_df

#scale the extra_df 
extra_df[['h','top','base','wavelength']] = scaler_1.transform(extra_df[['h','top','base','wavelength']])

# %%
extra_df[['h','top',	'base',	'wavelength']]
# Out:
#            h    top      base  wavelength
# 0   0.208333  0.175  0.144444  1332.00000
# 1   0.208333  0.175  0.144444  1342.10101
# 2   0.208333  0.175  0.144444  1352.20202
# 3   0.208333  0.175  0.144444  1362.30303
# 4   0.208333  0.175  0.144444  1372.40404
# ..       ...    ...       ...         ...
# 95  0.333333  0.500  0.444444  2291.59596
# 96  0.333333  0.500  0.444444  2301.69697
# 97  0.333333  0.500  0.444444  2311.79798
# 98  0.333333  0.500  0.444444  2321.89899
# 99  0.333333  0.500  0.444444  2332.00000
#
# [1100 rows x 4 columns]

# %%
#Checking if there is any overfit and best models for validation sets for different epochs of training 
mean_mae_list_train_set = []
mean_mae_list_test_set = []
mean_mae_list_val_set = []
mean_mae_list_val2_set = []

std_mae_list_train_set = []
std_mae_list_test_set = []
std_mae_list_val_set = []
std_mae_list_val2_set = []
best_model_value = 10000000000

best_epoch = -1
best_rand = -1
for epochs_num in range(1700,1900,100):
    mae_list_train_set = []
    mae_list_test_set = []
    mae_list_val_set = []
    mae_list_val2_set = []
    print(epochs_num)
    for i in range(1,5,1):
        rand=random.randint(1, 10000)
        X_train, X_test, y_train, y_test = train_test_split(
        df4.drop(['Simulation index', 'Reflectance'], axis=1), # predictive variables
        df4['Reflectance'], # target
        test_size=0.2, # portion of dataset to allocate to test set
        random_state=rand, # we are setting the seed here
        )

        X_train.shape, X_test.shape
        n_inputs, n_outputs = X_train.shape[1],1
        model_forward = get_model(n_inputs, n_outputs)
        
        if (epochs_num == 100) & (i ==1):
            best_model = model_forward
            
        # fit model
        model_forward.fit(X_train, y_train, verbose=0, epochs = epochs_num)

        # evaluate model on test set
        mae_list_train_set.append( np.sqrt(model_forward.evaluate(X_train, y_train, verbose=0))*100/mean(y_train))
        test_error = np.sqrt(model_forward.evaluate(X_test, y_test, verbose=0))*100/mean(y_test)
        mae_list_test_set.append( np.sqrt(model_forward.evaluate(X_test, y_test, verbose=0) )*100/mean(y_test))
        #pred_2 = model.predict(df5[['h','top',	'base',	'wavelength']],df5['Reflectance'])
        mae_list_val_set.append(np.sqrt(model_forward.evaluate(df5[['h','top',	'base',	'wavelength']], df5['Reflectance'], verbose=0))*100/mean(df5['Reflectance']))
        mae_list_val2_set.append(np.sqrt(model_forward.evaluate(extra_df[['h','top',	'base',	'wavelength']], extra_df['Reflectance'], verbose=0))*100/mean(extra_df['Reflectance']))
        least_value = np.sqrt(model_forward.evaluate(extra_df[['h','top',	'base',	'wavelength']], extra_df['Reflectance'], verbose=0))*100/mean(extra_df['Reflectance'])
        
        print(mae_list_val2_set)
        if best_model_value>least_value:                                     
        	best_model_value = least_value
        	best_model = model_forward
        	best_epoch = epochs_num
        	best_rand = rand
        	best_train_error = test_error
        	print("best epoch: " ,best_epoch,"best_model_value error %: ", best_model_value,"random value: ",rand,"test error %: ",test_error)                                 
                                             
    mean_mae_list_test_set.append( np.mean(mae_list_test_set))
    mean_mae_list_val_set.append( np.mean(mae_list_val_set))
    mean_mae_list_val2_set.append( np.mean(mae_list_val2_set))
    
    std_mae_list_train_set.append( np.std(mae_list_train_set))
    std_mae_list_test_set.append( np.std(mae_list_test_set))
    std_mae_list_val_set.append( np.std(mae_list_val_set))
    std_mae_list_val2_set.append( np.std(mae_list_val2_set))
#pred= model.predict(X_test,y_test)
# Out:
# 1800
# [15665723.68983745]
# best epoch:  1800 best_model_value error %:  15665723.68983745 random value:  4896 test error %:  1.0991812392223936
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-443dd3059e08> in <module>
#      36
#      37         # fit model
# ---> 38         model_forward.fit(X_train, y_train, verbose=0, epochs = epochs_num)
#      39
#      40         # evaluate model on test set
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ...

# %%
mean(extra_df['Reflectance'])
# Out:
# 0.025009257568626958

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['mean_Final_RMSE'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
#ax1.legend(['mean_RMSE_percentage'],loc=2)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['training_rmse'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='black')
x_space = np.linspace(100, 1800, num=18)

line1 = ax1.errorbar(x_space,mean_mae_list_train_set, yerr=std_mae_list_train_set,ecolor='black',fmt='--^',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
ax1.legend(['train_set_mae'],loc=2)

line2 = ax1.errorbar(x_space,mean_mae_list_test_set, yerr=std_mae_list_test_set,ecolor='black',fmt='-*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='blue')
ax1.legend(['test_set_mae'],loc=2)

line3 = ax1.errorbar(x_space,mean_mae_list_val_set, yerr=std_mae_list_val_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='purple')
ax1.legend(['heldout_set_mae'],loc=2)

line4 = ax1.errorbar(x_space,mean_mae_list_val2_set, yerr=std_mae_list_val2_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='red')
#ax1.legend(['heldout_set_mae'],loc=2)

plt.legend(('mse_list_train', 'mse_list_test', 'mse_list_val','mse_list_external_data'),
           loc='upper center', shadow=True)
ylabel('Mean squared error (mse)',fontsize=15)
plt.xlabel('Num of epochs (arb. units)',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Deep Neural Networks with 80% train set',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =500
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %%
#normalized error

# %%
mean(extra_df['Reflectance'])
# Out:
# 0.025009257568626958

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['mean_Final_RMSE'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
#ax1.legend(['mean_RMSE_percentage'],loc=2)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['training_rmse'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='black')
x_space = np.linspace(100, 1800, num=18)


line1 = ax1.errorbar(x_space,mean_mae_list_train_set, yerr=std_mae_list_train_set,ecolor='black',fmt='--^',capthick=2,capsize=0,elinewidth=0.01, markersize=10,color='green')
ax1.legend(['train_set_mae'],loc=2)

line2 = ax1.errorbar(x_space,mean_mae_list_test_set, yerr=std_mae_list_test_set,ecolor='black',fmt='-*',capthick=2,capsize=0,elinewidth=0.01, markersize=10,color='blue')
ax1.legend(['test_set_mae'],loc=2)

line3 = ax1.errorbar(x_space,mean_mae_list_val_set, yerr=std_mae_list_val_set,ecolor='black',fmt='--*',capthick=2,capsize=0,elinewidth=0.01, markersize=10,color='purple')
ax1.legend(['heldout_set_mae'],loc=2)

line4 = ax1.errorbar(x_space,mean_mae_list_val2_set, yerr=std_mae_list_val2_set,ecolor='black',fmt='--*',capthick=2,capsize=0,elinewidth=0.01, markersize=10,color='red')
#ax1.legend(['heldout_set_mae'],loc=2)

plt.legend(('mse_list_train', 'mse_list_test', 'mse_list_val','mse_list_external_data'),
           loc='upper center', shadow=True)
ylabel('Mean squared error (mse)',fontsize=15)
plt.xlabel('Num of epochs (arb. units)',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Deep Neural Networks with 80% train set',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =500
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)

show()

# %%
np.sqrt([2,4])
# Out:
# array([1.41421356, 2.        ])

# %%
from pylab import figure, show, legend, ylabel
import matplotlib.ticker as ticker
# create the general figure
fig1 = figure(figsize=(9,8))
# and the first axes using subplot populated with data 
ax1 = fig1.add_subplot(111)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['mean_Final_RMSE'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
#ax1.legend(['mean_RMSE_percentage'],loc=2)
#line1 = ax1.errorbar(df_for1 ['Train_size'],df_for1 ['training_rmse'], yerr=df_for1 ['std_final_rmse'],ecolor='black',fmt='--o',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='black')
x_space = np.linspace(100, 1800, num=18)

line1 = ax1.errorbar(x_space,mean_mae_list_train_set, yerr=std_mae_list_train_set,ecolor='black',fmt='--^',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='green')
ax1.legend(['train_set_mae'],loc=2)

line2 = ax1.errorbar(x_space,mean_mae_list_test_set, yerr=std_mae_list_test_set,ecolor='black',fmt='-*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='blue')
ax1.legend(['test_set_mae'],loc=2)

line3 = ax1.errorbar(x_space,mean_mae_list_val_set, yerr=std_mae_list_val_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='purple')
ax1.legend(['heldout_set_mae'],loc=2)

line4 = ax1.errorbar(x_space,mean_mae_list_val2_set, yerr=std_mae_list_val2_set,ecolor='black',fmt='--*',capthick=2,capsize=5,elinewidth=0.8, markersize=10,color='red')
#ax1.legend(['heldout_set_mae'],loc=2)

plt.legend(('mae_list_train', 'mae_list_test', 'mae_list_val','mae_list_external_data'),
           loc='upper center', shadow=True)
ylabel('Mean absolut error (mae)',fontsize=15)
plt.xlabel('Num of epochs (arb. units)',fontsize=15)
# now, the second axes that shares the x-axis with the ax1
#ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
#line2 = ax2.errorbar(df_new5 ['Train_size'],df_new5 ['mean_relative_absolute_error'], yerr=df_new5 ['std_mean_relative_absolute_error'],ecolor='black',fmt='xr-',capthick=2)
#ax2.yaxis.tick_right()
#ax2.yaxis.set_label_position("right")
#ax2.legend(["mean_rel_absolute_error"],loc=1)
#ylabel('mean_rel_absolute_error')
plt.title('Deep Neural Networks with 80% train set',fontsize=15)
plt.xticks(rotation = 45)

tick_spacing =500
ax1.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

ax1.tick_params(direction='out', length=7, width=2,
                grid_alpha=0.5,labelsize=12)

#legend = ax1.legend(loc='down center', shadow=True, fontsize='x-large')

#ax1.set_yscale("log", nonposy='clip')
plt.grid(True)
plt.ylim(-0.00000025, 0.000001)
show()

# %%
#test best forward model

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_11.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_01.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_07.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= model_forward.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
import sklearn
sklearn.metrics.mean_absolute_error(df_test_out['Reflectance'], pre_heldout)
# Out:
# 0.0009431226422171224

# %%
np.sqrt(sklearn.metrics.mean_squared_error(df_test_out['Reflectance'], pre_heldout))/mean(extra_df['Reflectance'])
# Out:
# 0.029308343637317675

# %%
np.sqrt(sklearn.metrics.mean_squared_error(df_test_out['Reflectance'], pre_heldout))/mean(extra_df['Reflectance'])
# Out:
# 0.04929095556734695

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_02.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_03.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_04.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_05.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_06.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_07.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_08.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_09.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
#read the data with pandas and convert to a dataframe
df_test_out = pd.read_csv("extra_10.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3

df_test_out['base'] = df_test_out['base'] + df_test_out['top']
# scale it
df_test_out[['h','top','base','wavelength']] = scaler_1.transform(df_test_out[['h','top','base','wavelength']])

pre_heldout= best_model.predict(df_test_out.drop(['Reflectance'], axis=1))

plt.plot(df_test_out['wavelength'], pre_heldout,'r') 
plt.plot(df_test_out['wavelength'], df_test_out['Reflectance'], 'b')
plt.show()

# %%
df_test_out = pd.read_csv("extra_01.txt", sep = " ",skiprows=1,header = None,delimiter=r"\s+",names = ['h','top','base','wavelength','Reflectance'])

#convert to nanometers:
df_test_out['h'] = df_test_out['h']* 10**9
df_test_out['top'] = df_test_out['top']* 10**9
df_test_out['base'] = df_test_out['base']* 10**9
df_test_out['wavelength'] = df_test_out['wavelength']* 10**3
df_test_out['base'] = df_test_out['base'] + df_test_out['top']
df_test_out
# Out:
#         h   top  base  wavelength  Reflectance
# 0   105.0  17.0  40.0  400.000000     0.035341
# 1   105.0  17.0  40.0  403.030303     0.036392
# 2   105.0  17.0  40.0  406.060606     0.036706
# 3   105.0  17.0  40.0  409.090909     0.036880
# 4   105.0  17.0  40.0  412.121212     0.036973
# ..    ...   ...   ...         ...          ...
# 95  105.0  17.0  40.0  687.878788     0.026150
# 96  105.0  17.0  40.0  690.909091     0.026370
# 97  105.0  17.0  40.0  693.939394     0.026594
# 98  105.0  17.0  40.0  696.969697     0.026821
# 99  105.0  17.0  40.0  700.000000     0.027052
#
# [100 rows x 5 columns]

# %%
pred= best_model.predict(extra_df[['h','top',	'base',	'wavelength']])

plt.figure(figsize=(9,7))
plt.scatter(pred,extra_df['Reflectance'],alpha=0.6,s=3)
plt.plot([0, 0.05],[0, 0.05],'r',alpha=0.8)
plt.ylabel('True Reflectivity',fontsize=15)
plt.xlabel('Predicted Reflectivity ',fontsize=15)
plt.title('Deep Neural Network (Train size= 80% of data)',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#set_xlim(left, right)
plt.xlim([-0.01, 0.06])
plt.ylim([-0.01,  0.06])
plt.show()

# %% [markdown]
# # Next steps:
# * Check for the points that have high errors. What h, top, base they have?
# * Συζήτηση για SPIE
# * Κανονικοποίηση
